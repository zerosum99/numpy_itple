# %%
from IPython.display import Image

# %%
Image("C:\\Users\\MG\\Desktop\\칼무리\\넘파이9장/K-001.png")

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.19.2'

# %%
Image("C:\\Users\\MG\\Desktop\\칼무리\\넘파이9장/K-002.png")

# %% [markdown]
# 균등 분포 (uniform distribution)
#
# -확률 변수 x가 어떤 값을 취하든지 그 값이 나타날 확률이 달라지지 않고 전부 동일한 확률을 보이는 확률 분포
#
# : 이산분포 / 연속분포

# %% [markdown]
# ## 예제 9-1-1-1  균등분포 함수 알아보기

# %% [markdown]
# rand 함수
#
# - 균등 분포로 임의의 난수로 배열을 만드는 함수, 분포의 값은 0~1사이의 실수.

# %% [markdown]
# 1차원

# %%
a = np.random.rand(3)

# %%
a
# Out:
# array([0.32639613, 0.0914585 , 0.11671425])

# %% [markdown]
# 2차원

# %%
b = np.random.rand(3,3)

# %%
b
# Out:
# array([[0.19263333, 0.1645044 , 0.93481515],
#        [0.31326672, 0.98900773, 0.88709556],
#        [0.61422904, 0.87510936, 0.82250235]])

# %%
이미지 출력 예제

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = np.random.rand(30,30)

# %%
plt.imshow(image, cmap=plt.cm.hot)#생상의 맵 지정
plt.colorbar()#색상의 농도

plt.show()

# %% [markdown]
# random / random_sample / ranf

# %%
np.random.seed(100)
np.random.random((5,))
# Out:
# array([0.54340494, 0.27836939, 0.42451759, 0.84477613, 0.00471886])

# %%
np.random.seed(100)
np.random.random_sample((5,))
# Out:
# array([0.54340494, 0.27836939, 0.42451759, 0.84477613, 0.00471886])

# %%
np.random.seed(100)
np.random.ranf((5,))
# Out:
# array([0.54340494, 0.27836939, 0.42451759, 0.84477613, 0.00471886])

# %%
Image("C:\\Users\\MG\\Desktop\\칼무리\\넘파이9장/K-003.png")

# %%
x = np.random.randint(3,10,size=10)

# %%
x
# Out:
# array([5, 8, 5, 5, 9, 5, 4, 3, 3, 7])

# %%
y = np.random.randint(3,10,size=(3,3))

# %%
y
# Out:
# array([[6, 7, 5],
#        [3, 6, 4],
#        [8, 9, 5]])

# %%
x = np.random.uniform(0,1,10)

# %%
x
# Out:
# array([0.97862378, 0.81168315, 0.17194101, 0.81622475, 0.27407375,
#        0.43170418, 0.94002982, 0.81764938, 0.33611195, 0.17541045])

# %%
y = np.random.uniform(10,20,(3,3))

# %%
y
# Out:
# array([[13.72832046, 10.05688507, 12.52426353],
#        [17.95662508, 10.15254971, 15.98843377],
#        [16.03804539, 11.05147685, 13.81943445]])
