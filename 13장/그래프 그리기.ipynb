# %% [markdown]
# ## 참고자료
#
# http://pythonkr.github.io/pyconkr-2014/pdf/pyconkr-2014-07_networkx.pdf

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.17.2'

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import networkx as nx

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_nodes_from(['A','B','C','D'])
G.add_edges_from([('A','B'),('A','B'),('A','D'),('B','D'),('B','C'),('B','C'),('C','D')])
nx.draw(G)

# %%
G = nx.MultiGraph()
G.add_nodes_from(['A','B','C','D'])
G.add_edges_from([('A','B'),('A','B'),('A','D'),('B','D'),('B','C'),('B','C'),('C','D')])
nx.draw(G)

# %%
G.nodes()
# Out:
# NodeView(('A', 'B', 'C', 'D'))

# %%
G.edges()
# Out:
# MultiEdgeDataView([('A', 'B'), ('A', 'B'), ('A', 'D'), ('B', 'D'), ('B', 'C'), ('B', 'C'), ('C', 'D')])

# %%
G.edges(data=True)
# Out:
# MultiEdgeDataView([('A', 'B', {}), ('A', 'B', {}), ('A', 'D', {}), ('B', 'D', {}), ('B', 'C', {}), ('B', 'C', {}), ('C', 'D', {})])

# %%
G = nx.Graph()    #% 빈 그래프 구조 G 생성
G.add_edge(1,2)   #% 엣지 추가
nx.draw(G)

# %%
G.nodes()
# Out:
# NodeView((1, 2))

# %%
G.edges()
# Out:
# EdgeView([(1, 2)])

# %%
G = nx.Graph()
G.add_node('apple')   #% 노드 ‘apple’ 추가
G.add_nodes_from(['banana','kiwi','mango'])

fruits = ['_banana','_kiwi','_mango']
G.add_nodes_from(fruits)
nx.draw(G)

# %%
G.nodes()
# Out:
# NodeView(('apple', 'banana', 'kiwi', 'mango', '_banana', '_kiwi', '_mango'))

# %%
G.node['kiwi']
# Out:
# {}

# %%
G.node['kiwi']['kind'] = 'fruit'

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'apple': {}, 'banana': {}, 'kiwi': {'kind': 'fruit'}, 'mango': {}, '_banana': {}, '_kiwi': {}, '_mango': {}})

# %%
# Create a networkx graph object
my_graph = nx.Graph() 
 
# Add edges to to the graph object
# Each tuple represents an edge between two nodes
my_graph.add_edges_from([
                        (1,2), 
                        (1,3), 
                        (3,4), 
                        (1,5), 
                        (3,5),
                        (4,2),
                        (2,3),
                        (3,0)])
 
# Draw the resulting graph
nx.draw(my_graph, with_labels=True, font_weight='bold')

# %% [markdown]
# ## 노드에 속성 부여하기

# %%
G.add_node('_kiwi', kind='fruit')
G.add_nodes_from(['banana', 'apple'], kind='fruit')

# %%
G.node['banana']
# Out:
# {'kind': 'fruit'}

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'apple': {'kind': 'fruit'}, 'banana': {'kind': 'fruit'}, 'kiwi': {'kind': 'fruit'}, 'mango': {}, '_banana': {}, '_kiwi': {'kind': 'fruit'}, '_mango': {}})

# %% [markdown]
# ## 엣지에 속성 부여하기

# %%
G.edges(data=True)
# Out:
# EdgeDataView([])

# %%
# %%writefile node.txt
# node_1
# node_2
# node_3
# node_x
# Out:
# Overwriting node.txt

# %%
# %%writefile edge.txt
# node_1 node_2
# node_2 node_3
# node_3 node_1
# Out:
# Overwriting edge.txt

# %%
my_graph = nx.Graph()
edges = nx.read_edgelist('edge.txt')
nodes = nx.read_adjlist("node.txt")
my_graph.add_edges_from(edges.edges())
my_graph.add_nodes_from(nodes)
nx.draw(my_graph, with_labels=True, font_weight='bold')

# %%
edges

# %%
nodes

# %%
list(edges)
# Out:
# ['node_1', 'node_2', 'node_3']

# %%
list(nodes)
# Out:
# ['node_1', 'node_2', 'node_3', 'node_x']

# %%
g = nx.path_graph(10)
nx.draw(g)

# %%
g = nx.lollipop_graph(4,2)
nx.draw(g)

# %%
g= nx.ladder_graph(10)
nx.draw(g)

# %%
g = nx.hypercube_graph(3)
nx.draw(g)

# %%
g = nx.hypercube_graph(2)
nx.draw(g)

# %%
g = nx.hypercube_graph(4)
nx.draw(g)

# %%
g = nx.grid_graph(dim=[3,3,3])
nx.draw(g)

# %%
g.number_of_edges()
# Out:
# 54

# %%
g.number_of_nodes()
# Out:
# 27

# %%
g = nx.grid_2d_graph(3,3)
nx.draw(g)

# %%
g = nx.cycle_graph(5)
nx.draw(g)

# %%
g = nx.circular_ladder_graph(5)
nx.draw(g)

# %%
g = nx.complete_graph(5)
nx.draw(g)

# %%
g = nx.balanced_tree(2,2)
nx.draw(g)

# %%
g = nx.tree_graph(dict(id='id', children='children'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-c159f4623fd2> in <module>
# ----> 1 g = nx.tree_graph(dict(id='id', children='children'))
#
# ~/anaconda/lib/python3.6/site-packages/networkx/readwrite/json_graph/tree.py in tree_graph(data, attrs)
#     150                     if k != id_ and k != children)
#     151     graph.add_node(root, **nodedata)
# --> 152     add_children(root, children_)
#     153     return graph
#
# ~/anaconda/lib/python3.6/site-packages/networkx/readwrite/json_graph/tree.py in add_children(parent, children_)
#     136     def add_children(parent, children_):
#     137         for data in children_:
# --> 138             child = data[id_]
#     139             graph.add_edge(parent, child)
#     140             grandchildren = data.get(children, [])
#
# TypeError: string indices must be integers
